# %% [markdown]
# # EDA
# In this project, we will try to give answers to a set of questions that may be relevant when analyzing banking data:
#
# 1.  What is the share of clients attracted in our source data?
# 2.  What are the mean values ​​of numerical features among the attracted clients?
# 3.  What is the average call duration for the attracted clients?
# 4.  What is the average age among the attracted and unmarried clients?
# 5.  What is the average age and call duration for different types of client employment?
#
# In addition, we will make a visual analysis in order to plan marketing banking campaigns more effectively.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dataset/bank-additional.csv",sep=";")
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         -1.8          92.893          -46.2      1.313       5099.1  no
# 1          1.1          93.994          -36.4      4.855       5191.0  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3          1.4          94.465          -41.8      4.959       5228.1  no
# 4         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
#  17  cons.conf.idx   4119 non-null   float64
#  18  euribor3m       4119 non-null   float64
#  19  nr.employed     4119 non-null   float64
#  20  y               4119 non-null   object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 675.9+ KB

# %%
df.shape
# Out:
# (4119, 21)

# %% [markdown]
# ##  What are the mean values ​​of numerical features among the attracted clients?

# %%
df.loc[df["y"] == "yes"]
# Out:
#       age          job   marital            education default housing loan  \
# 19     50  blue-collar   married             basic.4y      no      no  yes
# 21     39   technician  divorced          high.school      no      no   no
# 25     38   technician   married  professional.course      no     yes   no
# 53     24   technician   married    university.degree      no     yes  yes
# 59     60       admin.  divorced  professional.course      no     yes   no
# ...   ...          ...       ...                  ...     ...     ...  ...
# 4034   74      retired   married    university.degree      no     yes  yes
# 4066   81      retired   married             basic.4y      no     yes   no
# 4069   60       admin.   married    university.degree      no     yes   no
# 4088   47   management   married    university.degree      no     yes   no
# 4089   25       admin.    single    university.degree      no     yes  yes
#
#        contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 19    cellular   jul         tue  ...         1    999         0  nonexistent
# 21    cellular   mar         mon  ...         1     12         2      success
# 25    cellular   aug         mon  ...         1    999         0  nonexistent
# 53    cellular   sep         tue  ...         2      3         1      success
# 59    cellular   sep         wed  ...         1    999         1      failure
# ...        ...   ...         ...  ...       ...    ...       ...          ...
# 4034  cellular   aug         wed  ...         3    999         0  nonexistent
# 4066  cellular   oct         wed  ...         1    999         2      failure
# 4069  cellular   may         mon  ...         2    999         0  nonexistent
# 4088  cellular   sep         mon  ...         1      3         2      success
# 4089  cellular   oct         fri  ...         1    999         1      failure
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 19            1.4          93.918          -42.7      4.961       5228.1  yes
# 21           -1.8          93.369          -34.8      0.639       5008.7  yes
# 25            1.4          93.444          -36.1      4.965       5228.1  yes
# 53           -3.4          92.379          -29.8      0.770       5017.5  yes
# 59           -1.1          94.199          -37.5      0.886       4963.6  yes
# ...           ...             ...            ...        ...          ...  ...
# 4034         -2.9          92.201          -31.4      0.854       5076.2  yes
# 4066         -1.1          94.601          -49.5      1.016       4963.6  yes
# 4069         -1.8          92.893          -46.2      1.354       5099.1  yes
# 4088         -3.4          92.379          -29.8      0.771       5017.5  yes
# 4089         -3.4          92.431          -26.9      0.739       5017.5  yes
#
# [451 rows x 21 columns]

# %%
df.loc[df["y"] == "no"].shape
# Out:
# (3668, 21)

# %%
df.loc[df["y"] == "yes"].describe().loc[df.loc[df["y"] == "yes"].describe().index=="mean"]
# Out:
#             age   duration  campaign       pdays  previous  emp.var.rate  \
# mean  41.889135  560.78714  1.980044  778.722838  0.585366     -1.177384
#
#       cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# mean       93.417268     -39.786475   2.145448  5093.118625

# %%
df.loc[df["pdays"]!=999]["pdays"].mean()
# Out:
# 5.8625

# %%
df.loc[df["y"] == "no"].describe().loc[df.loc[df["y"] == "no"].describe().index=="mean"]
# Out:
#             age   duration  campaign       pdays  previous  emp.var.rate  \
# mean  39.895311  219.40976   2.60578  982.763086  0.141767      0.240185
#
#       cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# mean       93.599677     -40.586723   3.802826  5175.502072

# %% [markdown]
#  ## What is the average call duration for the attracted clients?

# %%
df.loc[df["y"] == "yes"].describe().loc[df.loc[df["y"] == "yes"].describe().index=="mean"]["duration"]
# Out:
# mean    560.78714
# Name: duration, dtype: float64

# %% [markdown]
# ## What is the average age among the attracted and unmarried clients?

# %%
np.mean((df.loc[df["y"] == "yes"].loc[df["marital"] == "single"]["age"]))
# Out:
# 32.961290322580645

# %% [markdown]
# ## What is the average age and call duration for different types of client employment?

# %%
df["job"].unique()
# Out:
# array(['blue-collar', 'services', 'admin.', 'entrepreneur',
#        'self-employed', 'technician', 'management', 'student', 'retired',
#        'housemaid', 'unemployed', 'unknown'], dtype=object)

# %%
df.groupby(["job"]).mean()[["age","duration"]]
# Out:
# C:\Users\mehdi\AppData\Local\Temp\ipykernel_880\2718147506.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["job"]).mean()[["age","duration"]]
#                      age    duration
# job
# admin.         38.240119  261.871542
# blue-collar    39.265837  261.852941
# entrepreneur   42.202703  249.202703
# housemaid      45.672727  229.663636
# management     42.429012  246.799383
# retired        60.873494  311.789157
# self-employed  40.679245  254.924528
# services       38.513995  232.529262
# student        26.695122  287.134146
# technician     38.622287  253.286541
# unemployed     39.531532  249.801802
# unknown        46.846154  234.410256

# %% [markdown]
# # Visualization

# %%
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         -1.8          92.893          -46.2      1.313       5099.1  no
# 1          1.1          93.994          -36.4      4.855       5191.0  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3          1.4          94.465          -41.8      4.959       5228.1  no
# 4         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %%
sns.barplot(x=df["y"].value_counts().index,y=df["y"].value_counts().values)
# Out:
# <AxesSubplot: >

# %%
df.groupby(["job"])["y"].value_counts()
# Out:
# job            y
# admin.         no     879
#                yes    133
# blue-collar    no     823
#                yes     61
# entrepreneur   no     140
#                yes      8
# housemaid      no      99
#                yes     11
# management     no     294
#                yes     30
# retired        no     128
#                yes     38
# self-employed  no     146
#                yes     13
# services       no     358
#                yes     35
# student        no      63
#                yes     19
# technician     no     611
#                yes     80
# unemployed     no      92
#                yes     19
# unknown        no      35
#                yes      4
# Name: y, dtype: int64

# %%
plt.figure(figsize=(10,9))
df.groupby(["job"])["y"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='job,y'>

# %%
df["y_class"] = df["y"].map({"yes":1,"no":0})

# %%
plt.figure(figsize=(10,9))
sns.heatmap(df.corr())
# Out:
# C:\Users\mehdi\AppData\Local\Temp\ipykernel_880\1686268148.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["duration"].mean().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='duration'>

# %%
df["previous"].unique()
# Out:
# array([0, 2, 1, 3, 5, 4, 6], dtype=int64)

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["previous"].mean().plot(kind="pie",autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='previous'>

# %%
df["education"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='education'>

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["education"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='y,education'>

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'y_class'],
#       dtype='object')

# %%
plt.figure(figsize=(10,9))
df["default"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='default'>

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["default"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='y,default'>

# %%
plt.figure(figsize=(10,9))
df["housing"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='housing'>

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["housing"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='y,housing'>

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'y_class'],
#       dtype='object')

# %%
plt.figure(figsize=(10,9))
df["loan"].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='loan'>

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["loan"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='y,loan'>

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'y_class'],
#       dtype='object')

# %%
plt.figure(figsize=(10,9))
df["contact"].value_counts().plot(kind="pie",autopct ="%1.1f%%")
# Out:
# <AxesSubplot: ylabel='contact'>

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["contact"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='y,contact'>

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'y_class'],
#       dtype='object')

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["day_of_week"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='y,day_of_week'>

# %%
plt.figure(figsize=(10,9))
df.groupby(["y"])["month"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='y,month'>

# %%
df.groupby(["y"])["campaign"].mean()
# Out:
# y
# no     2.605780
# yes    1.980044
# Name: campaign, dtype: float64

# %%
df.groupby(["y"])["campaign"].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='y'>

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'y_class'],
#       dtype='object')

# %%
df.groupby(["y"])["pdays"].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='y'>

# %%
df.groupby(['y'])["poutcome"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='y,poutcome'>

# %%
df.groupby(["y"])["emp.var.rate"].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='y'>

# %%
df.groupby(["y"])["emp.var.rate"].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='y'>

# %%
df.groupby(["y"])["cons.conf.idx"].mean()
# Out:
# y
# no    -40.586723
# yes   -39.786475
# Name: cons.conf.idx, dtype: float64

# %%
df.groupby(["y"])["euribor3m"].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='y'>

# %%
df.groupby(["y"])["nr.employed"].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='y'>

# %%
df.to_csv("data.csv")
